# %% [markdown]
# # NAME: PRAJWAL KV

# %% [markdown]
# # Let's import the necessary Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # IRIS Dataset has 150 rows and 6 columns

# %%
df=pd.read_csv('iris.csv')
print(df.shape,'\n')
print(df.info(),'\n')
print(df.describe())
# Out:
# (150, 6)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# None
#
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # Removed the ID column as it has no relation with dependent and independent variables

# %%
df.drop('Id',axis=1,inplace=True)

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # It seems like difficult to interpret co variance.Let's Try Correlation

# %%
df.cov()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       0.685694     -0.039268       1.273682      0.516904
# SepalWidthCm       -0.039268      0.188004      -0.321713     -0.117981
# PetalLengthCm       1.273682     -0.321713       3.113179      1.296387
# PetalWidthCm        0.516904     -0.117981       1.296387      0.582414

# %%
df.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %% [markdown]
# # Visualisation of Correlation .Petal Length and petal width are highly correlated(0.96).So from the visulaisation it's clear that independent features are highly correlated

# %%
sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# # EDA

# %%
sns.pairplot(data=df)

# %% [markdown]
# # There are 3 Duplicate values present in the Dataset

# %%
print(df.duplicated().sum())
# Out:
# 3

# %% [markdown]
# # Now Duplicate Values are Removed

# %%
df=df.drop_duplicates()
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# # No Null values are present in the dataset

# %%
df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='PiYG')#No null values

# %%
df['Species'].value_counts()
# Out:
# Iris-versicolor    50
# Iris-virginica     49
# Iris-setosa        48
# Name: Species, dtype: int64

# %% [markdown]
# # Iris-versicolor -   50
# # Iris-virginica  -   49
# # Iris-setosa     -   48

# %%
plt.figure(figsize=(15,6))
sns.set_style(style='whitegrid')
sns.countplot(x='Species',data=df)

# %%
sns.jointplot(x='SepalLengthCm',y='SepalWidthCm',data=df)

# %%
 sns.jointplot(x="PetalLengthCm", y="PetalWidthCm", data=df)

# %%
fig,ax=plt.subplots(figsize=(15,5))
sns.stripplot(x="PetalLengthCm", y="PetalWidthCm",hue='Species',data=df,split=True)

# %%
fig,ax=plt.subplots(figsize=(15,5))
sns.swarmplot(x='SepalLengthCm',y='SepalWidthCm',hue='Species',data=df,split=True)

# %% [markdown]
# # Preparing the data
# # The next step is to divide the data into "attributes" (inputs) and "labels" (outputs).

# %%
x=df.iloc[:,1:4]
y=df.Species

# %% [markdown]
# # Now that we have our attributes and labels, the next step is to split this data into training and test sets. We'll do this by using Scikit-Learn's built-in train_test_split() method:

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=7)

# %% [markdown]
# # Training the  DecisionTreeClassifier Algorithm.Model achieved a CV score of 94 % and also an  accuracy score of 89%

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier(criterion='entropy',min_samples_leaf=5,min_samples_split=25)
from sklearn.metrics import classification_report,confusion_matrix
from sklearn import metrics
from sklearn.model_selection import cross_val_score
dtree.fit(x_train,y_train)
predtree = dtree.predict(x_test)
print(classification_report(y_test,predtree),'\n')
print(confusion_matrix(y_test,predtree),'\n')
print("Accuracy:",metrics.accuracy_score(y_test,predtree),'\n')
print ("cv:",cross_val_score(dtree,x,y,cv=5,scoring = 'accuracy').mean())
print("Training Complete")
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       0.80      0.80      0.80        10
#  Iris-virginica       0.88      0.88      0.88        16
#
#        accuracy                           0.89        37
#       macro avg       0.89      0.89      0.89        37
#    weighted avg       0.89      0.89      0.89        37
#
#
# [[11  0  0]
#  [ 0  8  2]
#  [ 0  2 14]]
#
# Accuracy: 0.8918918918918919
#
# cv: 0.9450574712643679
# Training Complete

# %% [markdown]
# # Visual Representation of confusion matrix

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(dtree,x_test,y_test,cmap='viridis' )

# %% [markdown]
# # It's little difficult to interpret the Confusion matrix for Multi class labels.so that's why i wrote it down

# %% [markdown]
#  # Iris-setosa Confusion matrix

# %%
#True_Positive=11
#False_Positive=0
#False_Negative=0
#True_Negative=8+2+2+14=26

# %% [markdown]
# # Iris-versicolor  Confusion matrix

# %%
#True_Positive=8
#False_Positive=2
#False_Negative=0+2=2
#True_Negative=11+0+0+14=25

# %% [markdown]
#  # Iris-virginica  Confusion matrix

# %%
#True_Positive=14
#False_Positive=0+2=2
#False_Negative=0+2=2
#True_Negative=11+0+0+8=19

# %% [markdown]
# # Text Representation of Decison Tree

# %%
text_representation = tree.export_text(dtree)
print(text_representation)
# Out:
# |--- feature_1 <= 2.45
# |   |--- class: Iris-setosa
# |--- feature_1 >  2.45
# |   |--- feature_1 <= 4.85
# |   |   |--- feature_2 <= 1.45
# |   |   |   |--- class: Iris-versicolor
# |   |   |--- feature_2 >  1.45
# |   |   |   |--- class: Iris-versicolor
# |   |--- feature_1 >  4.85
# |   |   |--- feature_2 <= 1.75
# |   |   |   |--- class: Iris-virginica
# |   |   |--- feature_2 >  1.75
# |   |   |   |--- class: Iris-virginica

# %% [markdown]
# # Visualisation of Decision Tree

# %%
plt.figure(figsize=(15,5))
tree.plot_tree(dtree,filled=True)
plt.show()

# %% [markdown]
# # You can now feed any new/test data to this classifer and it would be able to predict the right class accordingly.
